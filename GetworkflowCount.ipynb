# %%
import os
import sys
import time
import requests
import urllib3
from datetime import datetime

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

TOKEN_URL = 'https://qa.onprem.icedq.com/auth/realms/icedq.qa/protocol/openid-connect/token'
token_data = {
    'grant_type': 'password',
    'client_id': 'icedq.admin-ui',
    'client_secret': 'b2e25665-7fce-49fa-9c63-f7c872dabcf2',
    'username': 'tapshyu.g',
    'password': 'Admin@1234'
}
token_response = requests.post(TOKEN_URL, data=token_data, verify=False)
access_token = token_response.json().get("access_token")
if not access_token:
    print("❌ Failed to get token.")
    exit()
WORKFLOW_RUNS = 'https://qa.onprem.icedq.com/api/v1/workflowruns/search?pageNo=1&pageSize=20&sort=updatedTimestamp:desc'
headers = {
    'accept': 'application/json, text/plain, */*',
    'account-id': 'acct-6f3fdf4c-9c27-5420-a6d5-476d2549dff6',
    'content-type': 'application/json',
    'org-id': 'org-icedq',
    'workspace-id': 'wksc-36655681-7ca9-58e1-b119-71ddb41cad1e',
    'authorization': f'Bearer {access_token}'
}
payload = {
    "filter": [
        {
            "attribute": "type",
            "operator": "Equals",
            "datatype": "string",
            "value": "workflow"
        }
    ],
    "updatedBetween": {
        "start": "08/01/2025 00:00:00 UTC",
        "end": "08/04/2025 23:59:00 UTC"
    }
}
response = requests.post(WORKFLOW_RUNS, headers=headers, json=payload, verify=False)
workflow_instance = response.json().get("items")
print(f"🗑️ Total workflow instance fount: { len(workflow_instance)}\n")
# Out:
# 🗑️ Total workflow instance fount: 6

# %%
import os
import sys
import time
import requests
import urllib3
from datetime import datetime

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

TOKEN_URL = 'https://192.168.100.76:32222/auth/realms/icedq/protocol/openid-connect/token'
token_data = {
    'grant_type': 'password',
    'client_id': 'icedq.admin-service',
    'client_secret': '0edc406d-ba4a-477c-96f2-72be355d6d98',
    'username': 'tapshyu',
    'password': 'Admin@1234'
}
token_response = requests.post(TOKEN_URL, data=token_data, verify=False)
access_token = token_response.json().get("access_token")
if not access_token:
    print("❌ Failed to get token.")
    exit()
WORKFLOW_RUNS = 'https://192.168.100.76:32222/api/v1/workflowruns/search?pageNo=1&pageSize=100000&sort=objectInstanceId:desc'
headers = {
    'accept': 'application/json, text/plain, */*',
    'account-id': 'acct-468c8372-9e3c-5c3e-a115-949d07b78dfc',
    'content-type': 'application/json',
    'org-id': 'org-icedq',
    'workspace-id': 'wksc-86d58331-3728-54b7-a5ae-1bd755c7878c',
    'authorization': f'Bearer {access_token}'
}
payload = {
    "filter": [
        {
            "attribute": "type",
            "operator": "Equals",
            "datatype": "string",
            "value": "workflow"
        },
        {
            "attribute": "status",
            "operator": "In",
            "datatype": "string",
            "value": "warning,error,success,blocker"
        }        
    ],
    "updatedBetween": {
        "start": "08/01/2025 09:00:00 UTC",
        "end": "08/04/2025 23:59:00 UTC"
    }
}
response = requests.post(WORKFLOW_RUNS, headers=headers, json=payload, verify=False)
workflow_instance = response.json().get("items")
print(f"🗑️ Total completed workflow instance found: { len(workflow_instance)}\n")
# Out:
# 🗑️ Total completed workflow instance found: 14595

# %%
import os
import sys
import time
import requests
import urllib3
from datetime import datetime

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

TOKEN_URL = 'https://qa.onprem.icedq.com/auth/realms/icedq.qa/protocol/openid-connect/token'
token_data = {
    'grant_type': 'password',
    'client_id': 'icedq.admin-ui',
    'client_secret': 'b2e25665-7fce-49fa-9c63-f7c872dabcf2',
    'username': 'tapshyu.g',
    'password': 'Admin@1234'
}
token_response = requests.post(TOKEN_URL, data=token_data, verify=False)
access_token = token_response.json().get("access_token")
print(access_token)
if not access_token:
    print("❌ Failed to get token.")
    exit()
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJOc1JIYVI2ckN0TTJSMlB5Z0tYYnd0OFBodWIyRG9FODNKTThMWWVCTFZjIn0.....O_C96pRdenF3oglJhhv5p21VN6W6HlFORoazBnvbeC-yeK4KhjWaJBRi4Kq61VX9Tndx7nkEamVn008r6nL_MMCak7lYo6Pmj6hIBwAAIx4gvcjyTrtqhLJ8BodEgy2zKE1AxGXIEmjJq8Y_2KlqdSE8n3LT6o1-21h9l4pLcmiTG57kZerWesGhwpfe12E_om0o5cviJtHEEMzY_WOEyAl1yebd1yIcel6J_6227tvKZQ9RHhEyG9ROmIoUZWFDRwHaVag0AgNJ28ATzx85ChpcuhRFLnuaa6PXhL24H5FC_RDXkPucomXm2LnHb1YDbb9fh1hgj2meUJU2zW1-7g

# %%
import os
import sys
import time
import requests
import urllib3
from datetime import datetime

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

TOKEN_URL = 'https://192.168.100.76:32222/auth/realms/icedq/protocol/openid-connect/token'
token_data = {
    'grant_type': 'password',
    'client_id': 'icedq.admin-service',
    'client_secret': '0edc406d-ba4a-477c-96f2-72be355d6d98',
    'username': 'tapshyu',
    'password': 'Admin@1234'
}
token_response = requests.post(TOKEN_URL, data=token_data, verify=False)
access_token = token_response.json().get("access_token")
if not access_token:
    print("❌ Failed to get token.")
    exit()
WORKFLOW_RUNS = 'https://192.168.100.76:32222/api/v1/workflowruns/search?pageNo=1&pageSize=100000&sort=objectInstanceId:desc'
headers = {
    'accept': 'application/json, text/plain, */*',
    'account-id': 'acct-468c8372-9e3c-5c3e-a115-949d07b78dfc',
    'content-type': 'application/json',
    'org-id': 'org-icedq',
    'workspace-id': 'wksc-86d58331-3728-54b7-a5ae-1bd755c7878c',
    'authorization': f'Bearer {access_token}'
}
payload = {
    "filter": [
        {
            "attribute": "type",
            "operator": "Equals",
            "datatype": "string",
            "value": "workflow"
        },
        {
            "attribute": "status",
            "operator": "In",
            "datatype": "string",
            "value": "running"
        }        
    ],
    "updatedBetween": {
        "start": "08/04/2025 08:30:00 UTC",
        "end": "08/06/2025 23:59:00 UTC"
    }
}
response = requests.post(WORKFLOW_RUNS, headers=headers, json=payload, verify=False)
workflow_instance = response.json().get("items")
print(f"🗑️ Total workflow running instance found: { len(workflow_instance)}\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 54
#      52 response = requests.post(WORKFLOW_RUNS, headers=headers, json=payload, verify=False)
#      53 workflow_instance = response.json().get("items")
# ---> 54 print(f"🗑️ Total workflow running instance found: { len(workflow_instance)}\n")
#
# TypeError: object of type 'NoneType' has no len()

# %%
import os
import sys
import time
import requests
import urllib3
from datetime import datetime

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

TOKEN_URL = 'https://192.168.100.76:32222/auth/realms/icedq/protocol/openid-connect/token'
token_data = {
    'grant_type': 'password',
    'client_id': 'icedq.admin-service',
    'client_secret': '0edc406d-ba4a-477c-96f2-72be355d6d98',
    'username': 'tapshyu',
    'password': 'Admin@1234'
}
token_response = requests.post(TOKEN_URL, data=token_data, verify=False)
access_token = token_response.json().get("access_token")
if not access_token:
    print("❌ Failed to get token.")
    exit()
WORKFLOW_RUNS = 'https://192.168.100.76:32222/api/v1/workflowruns/search?pageNo=1&pageSize=1000000&sort=objectInstanceId:desc'
headers = {
    'accept': 'application/json, text/plain, */*',
    'account-id': 'acct-468c8372-9e3c-5c3e-a115-949d07b78dfc',
    'content-type': 'application/json',
    'org-id': 'org-icedq',
    'workspace-id': 'wksc-86d58331-3728-54b7-a5ae-1bd755c7878c',
    'authorization': f'Bearer {access_token}'
}
payload = {
    "filter": [
        {
            "attribute": "type",
            "operator": "Equals",
            "datatype": "string",
            "value": "workflow"
        },
        {
            "attribute": "status",
            "operator": "In",
            "datatype": "string",
            "value": "running,warning,error,success,blocker,submitted"
        }        
    ],
    "updatedBetween": {
         "start": "08/04/2025 08:30:00 UTC",
        "end": "08/06/2025 23:59:00 UTC"
    }
}
response = requests.post(WORKFLOW_RUNS, headers=headers, json=payload, verify=False)
workflow_instance = response.json().get("items")
print(f"🗑️ Total trigger workflow instance found: { len(workflow_instance)}\n")
# Out:
# 🗑️ Total trigger workflow instance found: 13639

# %%
import os
import sys
import time
import requests
import urllib3
from datetime import datetime

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

TOKEN_URL = 'https://192.168.100.76:32222/auth/realms/icedq/protocol/openid-connect/token'
token_data = {
    'grant_type': 'password',
    'client_id': 'icedq.admin-service',
    'client_secret': '0edc406d-ba4a-477c-96f2-72be355d6d98',
    'username': 'tapshyu',
    'password': 'Admin@1234'
}
token_response = requests.post(TOKEN_URL, data=token_data, verify=False)
access_token = token_response.json().get("access_token")
if not access_token:
    print("❌ Failed to get token.")
    exit()
WORKFLOW_RUNS = 'https://192.168.100.76:32222/api/v1/workflowruns/search?pageNo=1&pageSize=100000&sort=objectInstanceId:desc'
headers = {
    'accept': 'application/json, text/plain, */*',
    'account-id': 'acct-468c8372-9e3c-5c3e-a115-949d07b78dfc',
    'content-type': 'application/json',
    'org-id': 'org-icedq',
    'workspace-id': 'wksc-86d58331-3728-54b7-a5ae-1bd755c7878c',
    'authorization': f'Bearer {access_token}'
}
payload = {
    "filter": [
        {
            "attribute": "type",
            "operator": "Equals",
            "datatype": "string",
            "value": "workflow"
        },
        {
            "attribute": "status",
            "operator": "In",
            "datatype": "string",
            "value": "warning,error,success,blocker"
        }        
    ],
    "updatedBetween": {
           "start": "08/04/2025 08:30:00 UTC",
        "end": "08/06/2025 23:59:00 UTC"
    }
}
response = requests.post(WORKFLOW_RUNS, headers=headers, json=payload, verify=False)
workflow_instance = response.json().get("items")
print(f"🗑️ Total completed workflow instance found: { len(workflow_instance)}\n")
# Out:
# 🗑️ Total completed workflow instance found: 13639
